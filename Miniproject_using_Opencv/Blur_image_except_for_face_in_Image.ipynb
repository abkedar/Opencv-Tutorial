# %%
img_h = img_w = 28             # MNIST images are 28x28
img_size_flat = img_h * img_w  # 28x28=784, the total number of pixels
n_classes = 10                 # Number of classes, one class per digit

# %% [markdown]
# ### Install **pnslib.git** in order to import *cv2.CascadeClassifier* for face detecion in imported image

# %%
# install pnslib
# !pip install git+git://github.com/PnS2019/pnslib.git
# !wget https://pns2019.github.io/images/Lenna.png
# Out:
# ...
#   Cloning git://github.com/PnS2019/pnslib.git to /tmp/pip-req-build-e69bbi3h
#   Running command git clone -q git://github.com/PnS2019/pnslib.git /tmp/pip-req-build-e69bbi3h
# ...
#   Created wheel for pnslib: filename=pnslib-0.1.0a1-cp36-none-any.whl size=1489618 sha256=6171a453fd221eef27bfee059f4c1e84ae5547e6aa89fc9bbadde5bdfa058f37
#   Stored in directory: /tmp/pip-ephem-wheel-cache-tj20vw0l/wheels/a2/8e/a9/c62e72840009deaa723b3a113d5c3b90acac77098d16e90eca
# Successfully built pnslib
# --2020-08-01 06:34:49--  https://pns2019.github.io/images/Lenna.png
# Resolving pns2019.github.io (pns2019.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to pns2019.github.io (pns2019.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 473831 (463K) [image/png]
# Saving to: ‘Lenna.png.1’
#
# Lenna.png.1         100%[===================>] 462.73K  --.-KB/s    in 0.08s
#
# ...

# %% [markdown]
# ## Blur Image Background except Face

# %% [markdown]
# Just follow 4 step process, instruction and idea for reference to complete this project.
#
#
#
# 1.   Preform face Detection
# 2.   Extract face ROI
# 3.   Blur/anonymize Image
# 4.   Store original image face in blur image.

# %%
# Python code to reading an image using OpenCV 
#from google.colab.patches import cv2_imshow
import cv2 
import numpy as np 
from pnslib import utils
import matplotlib.pyplot as plt 
  
# Load the cascade
# load face cascade and eye cascade
face_cascade = cv2.CascadeClassifier(
    utils.get_haarcascade_path('haarcascade_frontalface_default.xml'))
eye_cascade = cv2.CascadeClassifier(
    utils.get_haarcascade_path('haarcascade_eye.xml'))

img = cv2.imread('/content/Lenna.png') 

# Convert into grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Detect faces
faces = face_cascade.detectMultiScale(img, 1.2, 5)

# Draw rectangle around the faces
for (x, y, w, h) in faces:
    new_img = cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure()
plt.imshow(img)
plt.show()

# %%
# Importing cv2 module 
from google.colab.patches import cv2_imshow
import cv2  
  
# bat.jpg is the batman image. 
img = cv2.imread('/content/Lenna.png')  

crop_img = img[y:y+h, x:x+w]
  
# make sure that you have saved it in the same folder 
# You can change the kernel size as you want 
blurImg = cv2.blur(img,(10,10))
blurImg[y:y+h, x:x+w] = crop_img
cv2_imshow(blurImg)

cv2.waitKey(0) 
#cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F4C46EDCEB8>
# -1

# %% [markdown]
# Reference : [Blur face of any inserted **Image**](https://www.pyimagesearch.com/2020/04/06/blur-and-anonymize-faces-with-opencv-and-python/)
